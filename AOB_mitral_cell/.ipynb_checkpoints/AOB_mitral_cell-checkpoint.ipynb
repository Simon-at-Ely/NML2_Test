# %%
# %pylab inline
import sys

from pyneuroml import pynml
from pyneuroml.lems.LEMSSimulation import LEMSSimulation
import neuroml as nml

from pyneuroml.pynml import print_comment_v
from pyneuroml.lems import generate_lems_file_for_neuroml

import numpy as np

def generate_Vm_vs_time_plot(NML2_file, 
                                        cell_id, 
                                     #   inj_amp_nA = 80,
                                     #   delay_ms = 20,
                                     #   inj_dur_ms = 0.5,
                                        sim_dur_ms = 1000, 
                                        dt = 0.05,
                                        temperature = "35",
                                        spike_threshold_mV=0.,
                                        plot_voltage_traces=False,
                                        show_plot_already=True, 
                                        simulator="jNeuroML",
                                        include_included=True):
                                            
	# simulation parameters                                            
    nogui = '-nogui' in sys.argv  # Used to supress GUI in tests for Travis-CI
    
    ref = "Test"
    print_comment_v("Generating Vm(mV) vs Time(ms) plot for cell %s in %s using %s"% # (Inj %snA / %sms dur after %sms delay)"%
        (cell_id, NML2_file, simulator))#, inj_amp_nA, inj_dur_ms, delay_ms))
    
    sim_id = 'Vm_%s'%ref
    duration = sim_dur_ms
    ls = LEMSSimulation(sim_id, sim_dur_ms, dt)
    
    ls.include_neuroml2_file(NML2_file, include_included=include_included)
    ls.assign_simulation_target('network')
    nml_doc = nml.NeuroMLDocument(id=cell_id)
    
    nml_doc.includes.append(nml.IncludeType(href=NML2_file))
    
    net = nml.Network(id="network", type='networkWithTemperature', temperature='%sdegC'%temperature)
    nml_doc.networks.append(net)
    
    #input_id = ("input_%s"%str(inj_amp_nA).replace('.','_'))
    #pg = nml.PulseGenerator(id=input_id,
    #                                delay="%sms"%delay_ms,
    #                                duration='%sms'%inj_dur_ms,
    #                                amplitude='%spA'%inj_amp_nA)
    #nml_doc.pulse_generators.append(pg)
    
    
    pop_id = 'single_cell'
    pop = nml.Population(id=pop_id, component='iMC1_cell_1_origin', size=1, type="populationList")
    
    inst = nml.Instance(id=0)
    pop.instances.append(inst)
    inst.location = nml.Location(x=0, y=0, z=0)
    net.populations.append(pop)
    
    # Add these to cells
    #input_list = nml.InputList(id='il_%s'%input_id,
    #                             component=pg.id,
    #                             populations=pop_id)
    #input = nml.Input(id='0',  target='../hhpop/0/hhcell',
    #                          destination="synapses")  
    
    #input_list.input.append(input)
    #net.input_lists.append(input_list)
    
    sim_file_name = '%s.sim.nml'%sim_id
    pynml.write_neuroml2_file(nml_doc, sim_file_name)
    ls.include_neuroml2_file(sim_file_name)


    disp0 = 'Voltage_display'
    ls.create_display(disp0,"Voltages", "-90", "50")
    ls.add_line_to_display(disp0, "V", "hhpop/0/hhcell/v", scale='1mV')
    
    of0 = 'Volts_file'
    ls.create_output_file(of0, "%s.v.dat"%sim_id)
    ls.add_column_to_output_file(of0, "V", "hhpop/0/hhcell/v")
    
    lems_file_name = ls.save_to_file()
    
    if simulator == "jNeuroML":
        results = pynml.run_lems_with_jneuroml(lems_file_name, 
                                                nogui=True, 
                                                load_saved_data=True, 
                                                plot=plot_voltage_traces,
                                                show_plot_already=False)
    elif simulator == "jNeuroML_NEURON":
        results = pynml.run_lems_with_jneuroml_neuron(lems_file_name, 
                                                nogui=True, 
                                                load_saved_data=True, 
                                                plot=plot_voltage_traces,
                                                show_plot_already=False)
                                                
 
    if show_plot_already:
        from matplotlib import pyplot as plt
        plt.show()
        #plt.plot("t","V")        
        #plt.title("Vm(mV) vs Time(ms) plot for cell %s in %s using %s (Inj %snA / %sms dur after %sms delay)"% 
        #    (cell_id, nml2_file, simulator, inj_amp_nA, inj_dur_ms, delay_ms))
        #plt.xlabel('Time (ms)')
        #plt.ylabel('Vmemb (mV)')
        #plt.legend(['Test'], loc='upper right')
        
        
    return of0     
    

    
generate_Vm_vs_time_plot('iMC1_cell_1_origin.cell.nml', 'iMC1_cell_1_origin', plot_voltage_traces =  True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# pyNeuroML >>> Generating Vm(mV) vs Time(ms) plot for cell iMC1_cell_1_origin in iMC1_cell_1_origin.cell.nml using jNeuroML
# pyNeuroML >>> Including in generated LEMS file: iMC1_cell_1_origin.cell.nml (/home/Simon/NML2_Test/AOB_mitral_cell/iMC1_cell_1_origin.cell.nml)
# pyNeuroML >>> Including in generated LEMS file: BK_IAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/BK_IAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: CaV_R_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/CaV_R_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: Gran_CaPool_98.nml (/home/Simon/NML2_Test/AOB_mitral_cell/Gran_CaPool_98.nml)
# pyNeuroML >>> Including in generated LEMS file: KA_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/KA_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: Kdr_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/Kdr_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: LeakConductance.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/LeakConductance.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: NaP_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/NaP_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: NaxSH0_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/NaxSH0_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: NaxSH10_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/NaxSH10_ChannelML.channel.nml)
# pyNeuroML >>> Executing: (java -Xmx400M  -jar  "/home/Simon/anaconda/lib/python2.7/site-packages/pyNeuroML-0.1.13-py2.7.egg/pyneuroml/lib/jNeuroML-0.7.6-jar-with-dependencies.jar" -validate Vm_Test.sim.nml ) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.7.6
# pyNeuroML >>>   jNeuroML >>  Validating: /home/Simon/NML2_Test/AOB_mitral_cell/Vm_Test.sim.nml
# pyNeuroML >>>   jNeuroML >>  Valid against schema and all tests
# pyNeuroML >>>   jNeuroML >>
# pyNeuroML >>>   jNeuroML >>    Warning, check: 10007 (Segment Groups should specify numberInternalDivisions in a <property> element as a child of <segmentGroup>) failed! ... SegmentGroup: filament_100000001_4, has incorrect location for <property> for numberInternalDivisions (should be child of <segmentGroup>)
# pyNeuroML >>>   jNeuroML >>    Warning, check: 10007 (Segment Groups should specify numberInternalDivisions in a <property> element as a child of <segmentGroup>) failed! ... SegmentGroup: filament_100000001_5, has incorrect location for <property> for numberInternalDivisions (should be child of <segmentGroup>)
# pyNeuroML >>>   jNeuroML >>    Warning, check: 10007 (Segment Groups should specify numberInternalDivisions in a <property> element as a child of <segmentGroup>) failed! ... SegmentGroup: filament_100000001_39, has incorrect location for <property> for numberInternalDivisions (should be child of <segmentGroup>)
# pyNeuroML >>>   jNeuroML >>
# pyNeuroML >>>   jNeuroML >>  Validated 1 files: 0 passed, 1 passed with warnings,
# pyNeuroML >>>   jNeuroML >>
# pyNeuroML >>>   jNeuroML >>
# pyNeuroML >>> Including in generated LEMS file: Vm_Test.sim.nml (/home/Simon/NML2_Test/AOB_mitral_cell/Vm_Test.sim.nml)
# pyNeuroML >>> Including in generated LEMS file: iMC1_cell_1_origin.cell.nml (/home/Simon/NML2_Test/AOB_mitral_cell/iMC1_cell_1_origin.cell.nml)
# pyNeuroML >>> Including in generated LEMS file: BK_IAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/BK_IAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: CaV_R_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/CaV_R_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: Gran_CaPool_98.nml (/home/Simon/NML2_Test/AOB_mitral_cell/Gran_CaPool_98.nml)
# pyNeuroML >>> Including in generated LEMS file: KA_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/KA_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: Kdr_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/Kdr_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: LeakConductance.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/LeakConductance.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: NaP_iAMC_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/NaP_iAMC_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: NaxSH0_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/NaxSH0_ChannelML.channel.nml)
# pyNeuroML >>> Including in generated LEMS file: NaxSH10_ChannelML.channel.nml (/home/Simon/NML2_Test/AOB_mitral_cell/NaxSH10_ChannelML.channel.nml)
# pyNeuroML >>> Written LEMS Simulation Vm_Test to file: LEMS_Vm_Test.xml
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/home/Simon/anaconda/lib/python2.7/site-packages/pyNeuroML-0.1.13-py2.7.egg/pyneuroml/lib/jNeuroML-0.7.6-jar-with-dependencies.jar"  LEMS_Vm_Test.xml  -nogui) in directory: .
# pyNeuroML >>> *** Problem running command: Command 'java -Xmx400M  -Djava.awt.headless=true -jar  "/home/Simon/anaconda/lib/python2.7/site-packages/pyNeuroML-0.1.13-py2.7.egg/pyneuroml/lib/jNeuroML-0.7.6-jar-with-dependencies.jar"  LEMS_Vm_Test.xml  -nogui' returned non-zero exit status 1
# pyNeuroML >>>  jNeuroML >>   jNeuroML v0.7.6
# pyNeuroML >>>  jNeuroML >>  Loading: /home/Simon/NML2_Test/AOB_mitral_cell/LEMS_Vm_Test.xml with jLEMS, NO GUI mode...
# pyNeuroML >>>  jNeuroML >>  org.neuroml.export.exceptions.ModelFeatureSupportException: Feature not supported in LEMS: MULTICOMPARTMENTAL_CELL_MODEL (Model with multicompartmental cell(s))
# pyNeuroML >>>  jNeuroML >>      Level of support for MULTICOMPARTMENTAL_CELL_MODEL in LEMS is insufficient: NONE
# pyNeuroML >>>  jNeuroML >>
# pyNeuroML >>>  jNeuroML >>  Info on supported features:
# pyNeuroML >>>  jNeuroML >>  Format: LEMS
# pyNeuroML >>>  jNeuroML >>      ✓ SINGLE_COMP_MODEL (Model with only a single component (no network)): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ NETWORK_MODEL (Network model): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ MULTI_CELL_MODEL (Network model with multiple cells in a population): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ MULTI_POPULATION_MODEL (Network model with multiple populations of cells): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ NETWORK_WITH_INPUTS_MODEL (Network model with external inputs to cells): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ NETWORK_WITH_PROJECTIONS_MODEL (Network model with projections between populations): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ NETWORK_WITH_GAP_JUNCTIONS_MODEL (Network model with gap junctions/electrical connections between cells): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ NETWORK_WITH_ANALOG_CONNS_MODEL (Network model with analog/continuously communicating connections between cells): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ ABSTRACT_CELL_MODEL (Model with abstract (non conductance based) cell(s)): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ COND_BASED_CELL_MODEL (Model with conductance based cell(s)): HIGH
# pyNeuroML >>>  jNeuroML >>      x MULTICOMPARTMENTAL_CELL_MODEL (Model with multicompartmental cell(s)): NONE
# pyNeuroML >>>  jNeuroML >>      ✓ CHANNEL_POPULATIONS_CELL_MODEL (Model with channel populations): HIGH
# pyNeuroML >>>  jNeuroML >>      x CHANNEL_DENSITY_ON_SEGMENT (Model with channel density specified per segment (aot segmentGroup)): NONE
# pyNeuroML >>>  jNeuroML >>      ✓ HH_CHANNEL_MODEL (Model with HH based ion channel(s)): HIGH
# pyNeuroML >>>  jNeuroML >>      ✓ KS_CHANNEL_MODEL (Model with kinetic scheme based ion channel(s)): MEDIUM
# pyNeuroML >>>  jNeuroML >>
# pyNeuroML >>>  jNeuroML >>  	at org.neuroml.export.utils.support.SupportLevelInfo.checkConversionSupported(SupportLevelInfo.java:144)
# pyNeuroML >>>  jNeuroML >>  	at org.neuroml.export.utils.Utils.loadLemsFile(Utils.java:390)
# pyNeuroML >>>  jNeuroML >>  	at org.neuroml.export.utils.Utils.runLemsFile(Utils.java:364)
# pyNeuroML >>>  jNeuroML >>  	at org.neuroml.JNeuroML.main(JNeuroML.java:468)
# pyNeuroML >>>  jNeuroML >>  INFO Jun 29,2016 11:01  (INFO) Loading LEMS file from: /home/Simon/NML2_Test/AOB_mitral_cell/LEMS_Vm_Test.xml
# pyNeuroML >>>  jNeuroML >>  INFO Jun 29,2016 11:01  (INFO) Reading from: /home/Simon/NML2_Test/AOB_mitral_cell/LEMS_Vm_Test.xml
# pyNeuroML >>>  jNeuroML >>  WARNING Jun 29,2016 11:01  (WARNING) Unused attribute in Component(id=Vm_Test type=Simulation): XMLAttribute(seed, 12345)  at: org.lemsml.jlems.core.type.Component.resolve(Component.java:538)
# pyNeuroML >>>  jNeuroML >>
# pyNeuroML >>> Reloading: Data loaded from ./Vm_Test.v.dat (jNeuroML)
# 'Volts_file'
